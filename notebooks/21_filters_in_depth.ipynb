# %% [markdown]
# ## Documentation
#
# To read more about filters, checkout the docs [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/filter-search-results.html).
#
# ![filters_in_depth](../images/filters_in_depth.png)

# %% [markdown]
# ## Connect to ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200')
client_info = es.info()
print('Connected to Elasticsearch!')
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'iNEgsrfzSs-A5IWMvnKk8w',
#  'name': '5af1aab6c380',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2024-08-05T10:05:34.233336849Z',
#              'build_flavor': 'default',
#              'build_hash': '1a77947f34deddb41af25e6f0ddb8e830159c179',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '9.11.1',
#              'minimum_index_compatibility_version': '7.0.0',
#              'minimum_wire_compatibility_version': '7.17.0',
#              'number': '8.15.0'}}

# %% [markdown]
# ## Index data

# %%
import json

from pprint import pprint

es.indices.delete(index='my_index', ignore_unavailable=True)
es.indices.create(index='my_index')

operations = []
clothes_documents = json.load(open("../data/clothes.json"))

for document in clothes_documents:
    operations.append({'index': {'_index': 'my_index'}})
    operations.append(document)

response = es.bulk(operations=operations)
pprint(response.body)
# Out:
# {'errors': False,
#  'items': [{'index': {'_id': '-ElfMZUB6odEtf1MP4I6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 0,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '-UlfMZUB6odEtf1MP4I6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 1,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '-klfMZUB6odEtf1MP4I6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 2,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '-0lfMZUB6odEtf1MP4I6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 3,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '_ElfMZUB6odEtf1MP4I6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 4,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '_UlfMZUB6odEtf1MP4I6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 5,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '_klfMZUB6odEtf1MP4I6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 6,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '_0lfMZUB6odEtf1MP4I6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 7,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'AElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 8,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'AUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 9,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'AklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 10,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'A0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 11,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'BElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 12,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'BUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 13,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'BklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 14,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'B0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 15,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'CElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 16,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'CUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 17,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'CklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 18,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'C0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 19,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'DElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 20,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'DUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 21,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'DklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 22,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'D0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 23,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'EElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 24,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'EUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 25,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'EklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 26,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'E0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 27,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'FElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 28,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'FUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 29,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'FklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 30,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'F0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 31,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'GElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 32,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'GUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 33,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'GklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 34,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'G0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 35,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'HElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 36,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'HUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 37,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'HklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 38,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'H0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 39,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'IElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 40,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'IUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 41,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'IklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 42,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'I0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 43,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'JElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 44,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'JUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 45,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'JklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 46,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'J0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 47,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'KElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 48,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'KUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 49,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'KklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 50,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'K0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 51,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'LElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 52,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'LUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 53,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'LklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 54,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'L0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 55,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'MElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 56,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'MUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 57,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'MklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 58,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'M0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 59,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'NElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 60,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'NUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 61,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'NklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 62,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'N0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 63,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'OElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 64,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'OUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 65,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'OklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 66,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'O0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 67,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'PElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 68,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'PUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 69,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'PklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 70,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'P0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 71,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'QElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 72,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'QUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 73,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'QklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 74,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Q0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 75,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'RElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 76,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'RUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 77,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'RklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 78,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'R0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 79,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'SElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 80,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'SUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 81,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'SklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 82,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'S0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 83,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'TElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 84,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'TUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 85,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'TklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 86,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'T0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 87,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'UElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 88,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'UUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 89,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'UklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 90,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'U0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 91,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'VElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 92,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'VUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 93,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'VklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 94,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'V0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 95,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WElfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 96,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WUlfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 97,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WklfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 98,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'W0lfMZUB6odEtf1MP4M6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 99,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}}],
#  'took': 24189700}

# %%
count = es.count(index='my_index')
print('Number of documents in index:', count.body['count'])
# Out:
# Number of documents in index: 0

# %% [markdown]
# ## Simple filters

# %% [markdown]
# Previously, we learned about compound queries. Using a boolean query, you can apply filters to narrow down documents based on specific criteria. In this simple example, we filter documents to keep only those where the brand is Adidas.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": [
                    {
                        "term": {
                            "brand": "adidas"
                        }
                    }
                ]
            }
        },
        "size": 100
    },
)

hits = response.body['hits']['hits']
print(f"Found {len(hits)} documents")
# Out:
# Found 0 documents

# %% [markdown]
# Here, we apply multiple filters using an AND operation to retain documents where the brand is Adidas and the color is yellow.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": [
                    {
                        "term": {
                            "color": "yellow"
                        }
                    },
                    {
                        "term": {
                            "brand": "adidas"
                        }
                    }
                ]
            }
        },
    },
)

hits = response.body['hits']['hits']
print(f"Found {len(hits)} documents")
# Out:
# Found 0 documents

# %% [markdown]
# ## Post filters

# %% [markdown]
# In this example, we'll explore the use of filters, aggregations, filtered aggregations, and post-filters.
#
# We start by narrowing our search to documents where the `brand` is `gucci`. Next, we apply aggregations to determine the document count for each color. We then define a filtered aggregation, `color_red`, which counts the models in documents where the color is `red`.
#
# Finally, a `post_filter` is used after performing the aggregations, refining the search results to include only documents with the color `red`.

# %%
es.indices.refresh(index='my_index')
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": {
                    "term": {
                        "brand": "gucci"
                    }
                }
            }
        },
        "aggs": {
            "colors": {
                "terms": {
                    "field": "color.keyword" # indexed as-is, keyword is not analyzed and exact match is required
                }
            },
            "color_red": {
                "filter": {
                    "term": {
                        "color.keyword": "red"
                    }
                },
                "aggs": {
                    "models": {
                        "terms": {
                            "field": "model.keyword" # exact match is required
                        }
                    }
                }
            }
        },
        "post_filter": {
            "term": {
                "color": "red"
            }
        },
        "size": 20
    }
)
pprint(response.body)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'color_red': {'doc_count': 12,
#                                 'models': {'buckets': [{'doc_count': 3,
#                                                         'key': 'model_1'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_14'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_16'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_2'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_26'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_28'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_3'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_4'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_6'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_8'}],
#                                            'doc_count_error_upper_bound': 0,
#                                            'sum_other_doc_count': 0}},
#                   'colors': {'buckets': [{'doc_count': 12, 'key': 'red'},
#                                          {'doc_count': 8, 'key': 'blue'},
#                                          {'doc_count': 6, 'key': 'green'},
#                                          {'doc_count': 4, 'key': 'yellow'}],
#                              'doc_count_error_upper_bound': 0,
#                              'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': '-ElfMZUB6odEtf1MP4I6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': '-klfMZUB6odEtf1MP4I6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_3'}},
#                    {'_id': '_ElfMZUB6odEtf1MP4I6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'AUlfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_4'}},
#                    {'_id': 'BElfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'DUlfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_2'}},
#                    {'_id': 'HUlfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_28'}},
#                    {'_id': 'JUlfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_6'}},
#                    {'_id': 'LUlfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_14'}},
#                    {'_id': 'OUlfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_26'}},
#                    {'_id': 'RUlfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_8'}},
#                    {'_id': 'TUlfMZUB6odEtf1MP4M6',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_16'}}],
#           'max_score': 0.0,
#           'total': {'relation': 'eq', 'value': 12}},
#  'timed_out': False,
#  'took': 3}

# %% [markdown]
# The `colors_aggregation` variable holds the count of documents associated with each color, as returned by the aggregation query.

# %%
# Display response sources, without the `post_filter`, some models may have multiple colors
hits = response.body['hits']['hits']
sources = [hit['_source'] for hit in hits]
sources
# Out:
# [{'brand': 'gucci', 'color': 'red', 'model': 'model_1'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_3'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_1'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_4'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_1'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_2'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_28'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_6'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_14'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_26'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_8'},
#  {'brand': 'gucci', 'color': 'red', 'model': 'model_16'}]

# %%
colors_aggregation = response.body['aggregations']['colors']
pprint(colors_aggregation)
# Out:
# {'buckets': [{'doc_count': 12, 'key': 'red'},
#              {'doc_count': 8, 'key': 'blue'},
#              {'doc_count': 6, 'key': 'green'},
#              {'doc_count': 4, 'key': 'yellow'}],
#  'doc_count_error_upper_bound': 0,
#  'sum_other_doc_count': 0}

# %% [markdown]
# The `color_red_aggregation` variable contains the results from the `color_red` filtered aggregation, which includes the count of models specifically for documents where the color is `red`.

# %%
color_red_aggregation = response.body['aggregations']['color_red']
pprint(color_red_aggregation)
# Out:
# {'doc_count': 12,
#  'models': {'buckets': [{'doc_count': 3, 'key': 'model_1'},
#                         {'doc_count': 1, 'key': 'model_14'},
#                         {'doc_count': 1, 'key': 'model_16'},
#                         {'doc_count': 1, 'key': 'model_2'},
#                         {'doc_count': 1, 'key': 'model_26'},
#                         {'doc_count': 1, 'key': 'model_28'},
#                         {'doc_count': 1, 'key': 'model_3'},
#                         {'doc_count': 1, 'key': 'model_4'},
#                         {'doc_count': 1, 'key': 'model_6'},
#                         {'doc_count': 1, 'key': 'model_8'}],
#             'doc_count_error_upper_bound': 0,
#             'sum_other_doc_count': 0}}

# %% [markdown]
# To get the search results after the post-filter has been applied, we access the `hits` from `response.body['hits']['hits']`. This allows us to iterate through each result and display details such as the shirt's brand, color, and model.

# %%
hits = response.body['hits']['hits']
for hit in hits:
    print(f"""Shirt brand: {hit['_source']['brand']}, color: {
          hit['_source']['color']}, and model: {hit['_source']['model']}""")
# Out:
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_3
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_4
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_2
# Shirt brand: gucci, color: red, and model: model_28
# Shirt brand: gucci, color: red, and model: model_6
# Shirt brand: gucci, color: red, and model: model_14
# Shirt brand: gucci, color: red, and model: model_26
# Shirt brand: gucci, color: red, and model: model_8
# Shirt brand: gucci, color: red, and model: model_16

# %% [markdown]
# ## Documentation
#
# To read more about filters, checkout the docs [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/filter-search-results.html).
#
# ![filters_in_depth](../images/filters_in_depth.png)

# %% [markdown]
# ## Connect to ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200')
client_info = es.info()
print('Connected to Elasticsearch!')
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'DlYG5m9gR3upn7qgaYyAJA',
#  'name': '3d37442d2591',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2024-08-05T10:05:34.233336849Z',
#              'build_flavor': 'default',
#              'build_hash': '1a77947f34deddb41af25e6f0ddb8e830159c179',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '9.11.1',
#              'minimum_index_compatibility_version': '7.0.0',
#              'minimum_wire_compatibility_version': '7.17.0',
#              'number': '8.15.0'}}

# %% [markdown]
# ## Index data

# %%
import json

from pprint import pprint

es.indices.delete(index='my_index', ignore_unavailable=True)
es.indices.create(index='my_index')

operations = []
clothes_documents = json.load(open("../data/clothes.json"))

for document in clothes_documents:
    operations.append({'index': {'_index': 'my_index'}})
    operations.append(document)

response = es.bulk(operations=operations)
pprint(response.body)
# Out:
# {'errors': False,
#  'items': [{'index': {'_id': 'bhiy8ZIB0kQCMOUuLgAS',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 0,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'bxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 1,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'cBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 2,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'cRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 3,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'chiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 4,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'cxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 5,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'dBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 6,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'dRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 7,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'dhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 8,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'dxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 9,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'eBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 10,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'eRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 11,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ehiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 12,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'exiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 13,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 14,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 15,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 16,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 17,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 18,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 19,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ghiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 20,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 21,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 22,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 23,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 24,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 25,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'iBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 26,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'iRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 27,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ihiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 28,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ixiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 29,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 30,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 31,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 32,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 33,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 34,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 35,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'khiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 36,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 37,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 38,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 39,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 40,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 41,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 42,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 43,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 44,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 45,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 46,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 47,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 48,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 49,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'oBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 50,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'oRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 51,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ohiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 52,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'oxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 53,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 54,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 55,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'phiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 56,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 57,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 58,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 59,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 60,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 61,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 62,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 63,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 64,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 65,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'sBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 66,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'sRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 67,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'shiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 68,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'sxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 69,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'tBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 70,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'tRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 71,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'thiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 72,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'txiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 73,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'uBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 74,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'uRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 75,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'uhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 76,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'uxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 77,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'vBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 78,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'vRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 79,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'vhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 80,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'vxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 81,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'wBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 82,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'wRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 83,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'whiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 84,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'wxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 85,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'xBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 86,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'xRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 87,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'xhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 88,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'xxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 89,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'yBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 90,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'yRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 91,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'yhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 92,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'yxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 93,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'zBiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 94,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'zRiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 95,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'zhiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 96,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'zxiy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 97,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '0Biy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 98,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '0Riy8ZIB0kQCMOUuLgAT',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 99,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}}],
#  'took': 16472705}

# %%
count = es.count(index='my_index')
print('Number of documents in index:', count.body['count'])
# Out:
# Number of documents in index: 100

# %% [markdown]
# ## Simple filters

# %% [markdown]
# Previously, we learned about compound queries. Using a boolean query, you can apply filters to narrow down documents based on specific criteria. In this simple example, we filter documents to keep only those where the brand is Adidas.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": [
                    {
                        "term": {
                            "brand": "adidas"
                        }
                    }
                ]
            }
        },
        "size": 100
    },
)

hits = response.body['hits']['hits']
print(f"Found {len(hits)} documents")
# Out:
# Found 23 documents

# %% [markdown]
# Here, we apply multiple filters using an AND operation to retain documents where the brand is Adidas and the color is yellow.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": [
                    {
                        "term": {
                            "color": "yellow"
                        }
                    },
                    {
                        "term": {
                            "brand": "adidas"
                        }
                    }
                ]
            }
        },
    },
)

hits = response.body['hits']['hits']
print(f"Found {len(hits)} documents")
# Out:
# Found 6 documents

# %% [markdown]
# ## Post filters

# %% [markdown]
# In this example, we'll explore the use of filters, aggregations, filtered aggregations, and post-filters.
#
# We start by narrowing our search to documents where the `brand` is `gucci`. Next, we apply aggregations to determine the document count for each color. We then define a filtered aggregation, `color_red`, which counts the models in documents where the color is `red`.
#
# Finally, a `post_filter` is used after performing the aggregations, refining the search results to include only documents with the color `red`.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": {
                    "term": {
                        "brand": "gucci"
                    }
                }
            }
        },
        "aggs": {
            "colors": {
                "terms": {
                    "field": "color.keyword"
                }
            },
            "color_red": {
                "filter": {
                    "term": {
                        "color.keyword": "red"
                    }
                },
                "aggs": {
                    "models": {
                        "terms": {
                            "field": "model.keyword"
                        }
                    }
                }
            }
        },
        "post_filter": {
            "term": {
                "color": "red"
            }
        },
        "size": 20
    }
)
pprint(response.body)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'color_red': {'doc_count': 12,
#                                 'models': {'buckets': [{'doc_count': 3,
#                                                         'key': 'model_1'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_14'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_16'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_2'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_26'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_28'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_3'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_4'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_6'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_8'}],
#                                            'doc_count_error_upper_bound': 0,
#                                            'sum_other_doc_count': 0}},
#                   'colors': {'buckets': [{'doc_count': 12, 'key': 'red'},
#                                          {'doc_count': 8, 'key': 'blue'},
#                                          {'doc_count': 6, 'key': 'green'},
#                                          {'doc_count': 4, 'key': 'yellow'}],
#                              'doc_count_error_upper_bound': 0,
#                              'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'bhiy8ZIB0kQCMOUuLgAS',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'cBiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_3'}},
#                    {'_id': 'chiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'dxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_4'}},
#                    {'_id': 'ehiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'gxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_2'}},
#                    {'_id': 'kxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_28'}},
#                    {'_id': 'mxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_6'}},
#                    {'_id': 'oxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_14'}},
#                    {'_id': 'rxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_26'}},
#                    {'_id': 'uxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_8'}},
#                    {'_id': 'wxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_16'}}],
#           'max_score': 0.0,
#           'total': {'relation': 'eq', 'value': 12}},
#  'timed_out': False,
#  'took': 5}

# %% [markdown]
# The `colors_aggregation` variable holds the count of documents associated with each color, as returned by the aggregation query.

# %%
colors_aggregation = response.body['aggregations']['colors']['buckets']
pprint(colors_aggregation)
# Out:
# [{'doc_count': 12, 'key': 'red'},
#  {'doc_count': 8, 'key': 'blue'},
#  {'doc_count': 6, 'key': 'green'},
#  {'doc_count': 4, 'key': 'yellow'}]

# %% [markdown]
# The `color_red_aggregation` variable contains the results from the `color_red` filtered aggregation, which includes the count of models specifically for documents where the color is `red`.

# %%
color_red_aggregation = response.body['aggregations']['color_red']['models']['buckets']
pprint(color_red_aggregation)
# Out:
# [{'doc_count': 3, 'key': 'model_1'},
#  {'doc_count': 1, 'key': 'model_14'},
#  {'doc_count': 1, 'key': 'model_16'},
#  {'doc_count': 1, 'key': 'model_2'},
#  {'doc_count': 1, 'key': 'model_26'},
#  {'doc_count': 1, 'key': 'model_28'},
#  {'doc_count': 1, 'key': 'model_3'},
#  {'doc_count': 1, 'key': 'model_4'},
#  {'doc_count': 1, 'key': 'model_6'},
#  {'doc_count': 1, 'key': 'model_8'}]

# %% [markdown]
# To get the search results after the post-filter has been applied, we access the `hits` from `response.body['hits']['hits']`. This allows us to iterate through each result and display details such as the shirt's brand, color, and model.

# %%
hits = response.body['hits']['hits']
for hit in hits:
    print(f"""Shirt brand: {hit['_source']['brand']}, color: {
          hit['_source']['color']}, and model: {hit['_source']['model']}""")
# Out:
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_3
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_4
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_2
# Shirt brand: gucci, color: red, and model: model_28
# Shirt brand: gucci, color: red, and model: model_6
# Shirt brand: gucci, color: red, and model: model_14
# Shirt brand: gucci, color: red, and model: model_26
# Shirt brand: gucci, color: red, and model: model_8
# Shirt brand: gucci, color: red, and model: model_16

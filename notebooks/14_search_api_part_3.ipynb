# %% [markdown]
# ## Documentation
#
# To read more about the search API, visit the docs [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-your-data.html) and [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-search.html).
#
# ![search_api_docs](../images/search_api_docs.png)

# %% [markdown]
# ## Connect to ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200')
client_info = es.info()
print('Connected to Elasticsearch!')
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'iNEgsrfzSs-A5IWMvnKk8w',
#  'name': '5af1aab6c380',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2024-08-05T10:05:34.233336849Z',
#              'build_flavor': 'default',
#              'build_hash': '1a77947f34deddb41af25e6f0ddb8e830159c179',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '9.11.1',
#              'minimum_index_compatibility_version': '7.0.0',
#              'minimum_wire_compatibility_version': '7.17.0',
#              'number': '8.15.0'}}

# %% [markdown]
# ## Inserting documents

# %%
es.indices.delete(index='my_index', ignore_unavailable=True)
es.indices.create(index='my_index')
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'my_index'})

# %% [markdown]
# Let's index the documents sequentially in both indices.

# %%
import json


dummy_data = json.load(open("../data/dummy_data_2.json"))
for _ in range(10):
    dummy_data += dummy_data

len(dummy_data)
# Out:
# 5120

# %% [markdown]
# Since, we have duplicated the dummy data so much, we ended up with `5120` documents. Let's use the `bulk API` since we learned it before to index all those documents rapidly.

# %%
operations = []
for document in dummy_data:
    operations.append({'index': {'_index': 'my_index'}})
    operations.append(document)

es.bulk(operations=operations)
# Out:
# ObjectApiResponse({'errors': False, 'took': 12731713, 'items': [{'index': {'_index': 'my_index', '_id': 'sUb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'skb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 's0b4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'tEb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 3, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'tUb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 4, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'tkb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 5, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 't0b4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 6, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'uEb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 7, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'uUb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 8, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'ukb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 9, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'u0b4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 10, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'vEb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 11, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'vUb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 12, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'vkb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 13, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'v0b4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 14, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'wEb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 15, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'wUb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 16, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'wkb4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 17, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_index', '_id': 'w0b4L5UB6odEtf1MZF2W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 18, '_primary_term': 1, 'status': 201}}, {'index': {'_ ...

# %% [markdown]
# ## Searching

# %% [markdown]
# ### 1. Size + From

# %% [markdown]
# In this example, we perform a search that retrieves 10 documents, starting from the 11th document (i.e., skipping the first 10 results). This demonstrates pagination using the `size` and `from` parameters.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "match_all": {}
        },
        "size": 10, # return only 10 documents
        "from": 10 # skip the first 10 documents
    },
)

for hit in response['hits']['hits']:
    print(hit['_source'])
# Out:
# {'message': 'This is an important keyword search result.', 'age': 25, 'price': 100.0}
# {'message': 'Another search result with an important keyword.', 'age': 30, 'price': 150.0}
# {'message': 'Keyword match in this result as well.', 'age': 40, 'price': 200.0}
# {'message': 'Important keyword again in this document.', 'age': 35, 'price': 120.0}
# {'message': 'Final document with the important keyword.', 'age': 28, 'price': 180.0}
# {'message': 'This is an important keyword search result.', 'age': 25, 'price': 100.0}
# {'message': 'Another search result with an important keyword.', 'age': 30, 'price': 150.0}
# {'message': 'Keyword match in this result as well.', 'age': 40, 'price': 200.0}
# {'message': 'Important keyword again in this document.', 'age': 35, 'price': 120.0}
# {'message': 'Final document with the important keyword.', 'age': 28, 'price': 180.0}

# %% [markdown]
# ### 2. Timeout

# %% [markdown]
# This example shows how to set a timeout for the search query. If the query takes longer than the specified `10s` (10 seconds), it will be aborted.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "match": {
                "message": "search keyword"
            }
        },
        "timeout": "10s"
    },
)

response.body
# Out:
# {'took': 10,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 5120, 'relation': 'eq'},
#   'max_score': 0.8941701,
#   'hits': [{'_index': 'my_index',
#     '_id': 'sUb4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'This is an important keyword search result.',
#      'age': 25,
#      'price': 100.0}},
#    {'_index': 'my_index',
#     '_id': 'skb4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'Another search result with an important keyword.',
#      'age': 30,
#      'price': 150.0}},
#    {'_index': 'my_index',
#     '_id': 'tkb4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'This is an important keyword search result.',
#      'age': 25,
#      'price': 100.0}},
#    {'_index': 'my_index',
#     '_id': 't0b4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'Another search result with an important keyword.',
#      'age': 30,
#      'price': 150.0}},
#    {'_index': 'my_index',
#     '_id': 'u0b4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'This is an important keyword search result.',
#      'age': 25,
#      'price': 100.0}},
#    {'_index': 'my_index',
#     '_id': 'vEb4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'Another search result with an important keyword.',
#      'age': 30,
#      'price': 150.0}},
#    {'_index': 'my_index',
#     '_id': 'wEb4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'This is an important keyword search result.',
#      'age': 25,
#      'price': 100.0}},
#    {'_index': 'my_index',
#     '_id': 'wUb4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'Another search result with an important keyword.',
#      'age': 30,
#      'price': 150.0}},
#    {'_index': 'my_index',
#     '_id': 'xUb4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'This is an important keyword search result.',
#      'age': 25,
#      'price': 100.0}},
#    {'_index': 'my_index',
#     '_id': 'xkb4L5UB6odEtf1MZF2W',
#     '_score': 0.8941701,
#     '_source': {'message': 'Another search result with an important keyword.',
#      'age': 30,
#      'price': 150.0}}]}}

# %% [markdown]
# ### 3. Aggregation

# %% [markdown]
# In this example, we perform an aggregation to calculate the average value of the `age` field across all documents that match the query. The result of the aggregation is stored in the `avg_age` key.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "match_all": {}
        },
        "aggs": {
            "avg_age": {
                "avg": {
                    "field": "age"
                }
            }
        }
    }
)

average_age = response['aggregations']['avg_age']['value']
print(f"Average Age: {average_age}")
# Out:
# Average Age: 31.6

# %% [markdown]
# ### 4. Combining size, from, timeout, and aggs

# %% [markdown]
# Here we combine multiple parameters: we limit the results to 5 documents (`size`), skip the first 20 documents (`from`), set a timeout of 5 seconds (`timeout`), and perform a maximum aggregation (`aggs`) on the `price` field. This demonstrates how to use multiple search parameters together.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "match": {
                "message": "important keyword"
            }
        },
        "aggs": { # This aggregation will use all the documents that match the query, not just the size of 5 documents that are returned
            "max_price": {
                "max": {
                    "field": "price"
                }
            }
        },
        "size": 5,
        "from": 20,
        "timeout": "5s"
    },
)

for hit in response['hits']['hits']:
    print(hit['_source'])

max_price = response['aggregations']['max_price']['value']
print(f"Max Price: {max_price}")
# Out:
# {'message': 'Important keyword again in this document.', 'age': 35, 'price': 120.0}
# {'message': 'Final document with the important keyword.', 'age': 28, 'price': 180.0}
# {'message': 'Important keyword again in this document.', 'age': 35, 'price': 120.0}
# {'message': 'Final document with the important keyword.', 'age': 28, 'price': 180.0}
# {'message': 'Important keyword again in this document.', 'age': 35, 'price': 120.0}
# Max Price: 200.0
